# %%
import numpy as np
cricket_scores=[10,12,15,100]
median_scores=np.median(cricket_scores)
print(f"median:{median_scores}")
# Out:
# median:13.5

# %%
from statistics import mode
votes=[1,2,3,4,6,6,7,9,9,9,10]
most_common=mode(votes)
print(most_common)
# Out:
# 9

# %%
import numpy as np
tight_data= [60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
#simulating random predictions
for i in range (5):
  prediction=random.choice(["spam","not spam"])
  print(f"Email{i+1}:{prediction}")
# Out:
# Email1:not spam
# Email2:not spam
# Email3:not spam
# Email4:spam
# Email5:not spam

# %%
import random
#simulates 10 dice rolls
samples=[random.randint(1,6)
       for _  in range(10)]
print("samples rolls:",samples)
print("samples mean:",sum(samples)/len(samples))
# Out:
# samples rolls: [3, 1, 2, 4, 1, 6, 5, 6, 5, 5]
# samples mean: 3.8

# %%
import numpy as np
scores=[10,12,15,100]
print(np.mean(scores))
# Out:
# 34.25
