# %%
vegetables=["onion","cucumber","pumpkin"]
print(vegetables[0])
# Out:
# onion

# %%
vegetables=["onion","cucumber","pumpkin"]
print(vegetables[1])
# Out:
# cucumber

# %%
vegetables=("onion","cucumber","pumpkin")
print(vegetables[2])
# Out:
# pumpkin

# %%
students=[]
students.append("maithri")
students.append("kusuma")
students. append("sarika")
students.append("likitha")
print(students)
# Out:
# ['maithri', 'kusuma', 'sarika', 'likitha']

# %%
coordinates=(10,20)
print(coordinates[1])
# Out:
# 20

# %%
number={5,6,7,6,6,9,4,}
print(number)
# Out:
# {4, 5, 6, 7, 9}

# %%
student={
    "name":"maithri",
    "age":22,
    "course":"BSC",
}
print(student["course"])
# Out:
# BSC

# %%
marks={
    "math":85,
    "science":95,
}
marks["english"]=86
print(marks)
# Out:
# {'math': 85, 'science': 95, 'english': 86}
