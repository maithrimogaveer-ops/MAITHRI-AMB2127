# %%
rows=int(input("enter rows:"))
cols=int(input("enter columns"))
for i in range(rows):
  for j in range(cols):
    print("#",end="")
    print()
# Out:
# enter rows:2
# enter columns8
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %%
for i in range(3):
  j=0
  while j<2:
    print(i,j)
    j+=1
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
for i in range (2):
  for j in range(3):
    print("i=",i,"j=",j)
    print(i,j)
# Out:
# i= 0 j= 0
# 0 0
# i= 0 j= 1
# 0 1
# i= 0 j= 2
# 0 2
# i= 1 j= 0
# 1 0
# i= 1 j= 1
# 1 1
# i= 1 j= 2
# 1 2

# %%
fruit=["apple","banana","mango"]
print(fruit[0])
# Out:
# apple

# %%
fruit=["apple","banana","mango"]
print(fruit[1])
# Out:
# banana

# %%
day="tuesday"
if(day=="saturday"):
  print("colour dress")
else:
  print("uniform")
# Out:
# uniform

# %%
student={
    "name":"ravi",
    "age":20,
    "course":"bsc",
}
print(student["course"])
# Out:
# bsc
